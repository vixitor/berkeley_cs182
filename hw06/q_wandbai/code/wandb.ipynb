# %% [markdown]
# # Exploring Tooling with Weights and Biases
# Similar to tensorboard, weights and biases is an application that tracks all your training metrics, and performs visualizations for you. This tool allows you to cleanly sort, organize, and visualize your experiments. In this notebook, we will go through an example of how to use wandb.ai and have you practice.
#
# 1. Make an account at https://wandb.ai/site
#
# 2. pip install wandb
#
# 3. wandb login
#
# 4. After step 3, please paste your wandb API key

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import wandb
from architectures import BasicConvNet, ResNet18, MLP

# %% [markdown]
# ## Organizing wandb Projects
#
# With each run, you will want to have a set of parameters associated with it. For example, I want to be able to log different hyperparameters that I am using, so let's clearly list them below

# %%
project = 'CS182 WANDB.AI Practice Notebok'
learning_rate = 0.01
epochs = 2
architecture ='CNN'
dataset = 'CIFAR-10'
batch_size = 64
momentum = 0.9
log_freq = 20
print_freq = 200
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

# %% [markdown]
# ### Initializing the Run

# %%
wandb.login(key="a92fde442f3d127fc4f2f0566051842b96eea175")
# !rm -rf wandb
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/whe/.netrc

# %%
wandb.init(
    # set the wandb project where this run will be logged
    project=project,
    
    # track hyperparameters and run metadata
    config={
    "learning_rate": learning_rate,
    "architecture": architecture,
    "dataset": dataset,
    "epochs": epochs,
    "batch_size": batch_size,
    "momentum": momentum
    },
    mode='dryrun'  # change to 'online' to log to wandb.ai
)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/response_handle.py:105, in MailboxResponseHandle.wait_async(self, timeout)
#     104 try:
# --> 105     await asyncio.wait_for(evt.wait(), timeout=timeout)
#     107 except (asyncio.TimeoutError, TimeoutError) as e:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/asyncio/tasks.py:501, in wait_for(fut, timeout, loop)
#     500         await _cancel_and_wait(fut, loop=loop)
# --> 501         raise exceptions.TimeoutError()
#     502 finally:
#
# TimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/wandb_init.py:996, in _WandbInit.init(self, settings, config, run_printer)
#     995 try:
# --> 996     result = wait_with_progress(
#     997         run_init_handle,
#     998         timeout=timeout,
#     999         progress_after=1,
#    1000         display_progress=display_init_message,
#    1001     )
#    1003 except TimeoutError:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/wait_with_progress.py:24, in wait_with_progress(handle, timeout, progress_after, display_progress)
#      20 """Wait for a handle, possibly displaying progress to the user.
#      21
#      22 Equivalent to passing a single handle to `wait_all_with_progress`.
#      23 """
# ---> 24 return wait_all_with_progress(
#      25     [handle],
#      26     timeout=timeout,
#      27     progress_after=progress_after,
#      28     display_progress=display_progress,
#      29 )[0]
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/wait_with_progress.py:87, in wait_all_with_progress(handle_list, timeout, progress_after, display_progress)
#      82         return await _wait_handles_async(
#      83             handle_list,
#      84             timeout=remaining_timeout,
#      85         )
# ---> 87 return asyncio_compat.run(progress_loop_with_timeout)
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/asyncio_compat.py:30, in run(fn)
#      29 try:
# ---> 30     return future.result()
#      32 finally:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/concurrent/futures/_base.py:444, in Future.result(self, timeout)
#     443 elif self._state == FINISHED:
# --> 444     return self.__get_result()
#     445 else:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/concurrent/futures/_base.py:389, in Future.__get_result(self)
#     388 try:
# --> 389     raise self._exception
#     390 finally:
#     391     # Break a reference cycle with the exception in self._exception
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/concurrent/futures/thread.py:57, in _WorkItem.run(self)
#      56 try:
# ---> 57     result = self.fn(*self.args, **self.kwargs)
#      58 except BaseException as exc:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/asyncio_compat.py:74, in _Runner.run(self, fn)
#      66 """Run a coroutine in asyncio, cancelling it on `cancel()`.
#      67
#      68 Returns:
#    (...)
#      72     _RunnerCancelledError: If `cancel()` is called.
#      73 """
# ---> 74 return asyncio.run(self._run_or_cancel(fn))
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/asyncio/runners.py:44, in run(main, debug)
#      43         loop.set_debug(debug)
# ---> 44     return loop.run_until_complete(main)
#      45 finally:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/asyncio/base_events.py:616, in BaseEventLoop.run_until_complete(self, future)
#     614     raise RuntimeError('Event loop stopped before Future completed.')
# --> 616 return future.result()
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/asyncio_compat.py:98, in _Runner._run_or_cancel(self, fn)
#      97 if fn_task.done():
# ---> 98     return fn_task.result()
#      99 else:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/wait_with_progress.py:82, in wait_all_with_progress.<locals>.progress_loop_with_timeout()
#      80     remaining_timeout = None
# ---> 82 return await _wait_handles_async(
#      83     handle_list,
#      84     timeout=remaining_timeout,
#      85 )
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/wait_with_progress.py:132, in _wait_handles_async(handle_list, timeout)
#     131     for index in range(len(handle_list)):
# --> 132         task_group.start_soon(wait_single(index))
#     134 # NOTE: `list` is not subscriptable until Python 3.10, so we use List.
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/contextlib.py:178, in _AsyncGeneratorContextManager.__aexit__(self, typ, value, traceback)
#     177 try:
# --> 178     await self.gen.__anext__()
#     179 except StopAsyncIteration:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/asyncio_compat.py:190, in open_task_group()
#     189     yield task_group
# --> 190     await task_group._wait_all()
#     191 finally:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/asyncio_compat.py:159, in TaskGroup._wait_all(self)
#     158     if exc := task.exception():
# --> 159         raise exc
#     160 except asyncio.CancelledError:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/wait_with_progress.py:128, in _wait_handles_async.<locals>.wait_single(index)
#     127 handle = handle_list[index]
# --> 128 results[index] = await handle.wait_async(timeout=timeout)
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/mailbox_handle.py:122, in _MailboxMappedHandle.wait_async(self, timeout)
#     120 @override
#     121 async def wait_async(self, *, timeout: float | None) -> _S:
# --> 122     response = await self._handle.wait_async(timeout=timeout)
#     123     return self._fn(response)
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/mailbox/response_handle.py:114, in MailboxResponseHandle.wait_async(self, timeout)
#     113         else:
# --> 114             raise TimeoutError(
#     115                 f"Timed out waiting for response on {self._address}"
#     116             ) from e
#     118 else:
#
# TimeoutError: Timed out waiting for response on x837nzmpy0qj
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 wandb.init(
#       2     # set the wandb project where this run will be logged
#       3     project=project,
#       4
#       5     # track hyperparameters and run metadata
#       6     config={
#       7     "learning_rate": learning_rate,
#       8     "architecture": architecture,
#       9     "dataset": dataset,
#      10     "epochs": epochs,
#      11     "batch_size": batch_size,
#      12     "momentum": momentum
#      13     },
#      14     mode='dryrun'  # change to 'online' to log to wandb.ai
#      15 )
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/wandb_init.py:1620, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1616     wl._get_logger().exception("error in wandb.init()", exc_info=e)
#    1618 # Need to build delay into this sentry capture because our exit hooks
#    1619 # mess with sentry's ability to send out errors before the program ends.
# -> 1620 wandb._sentry.reraise(e)
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/analytics/sentry.py:157, in Sentry.reraise(self, exc)
#     154 self.exception(exc)
#     155 # this will messily add this "reraise" function to the stack trace,
#     156 # but hopefully it's not too bad
# --> 157 raise exc.with_traceback(sys.exc_info()[2])
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/wandb_init.py:1606, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1603         if run_settings.x_server_side_derived_summary:
#    1604             init_telemetry.feature.server_side_derived_summary = True
# -> 1606         return wi.init(run_settings, run_config, run_printer)
#    1608 except KeyboardInterrupt as e:
#    1609     if wl:
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/wandb_init.py:1009, in _WandbInit.init(self, settings, config, run_printer)
#    1004     run_init_handle.cancel(backend.interface)
#    1006     # This may either be an issue with the W&B server (a CommError)
#    1007     # or a bug in the SDK (an Error). We cannot distinguish between
#    1008     # the two causes here.
# -> 1009     raise CommError(
#    1010         f"Run initialization has timed out after {timeout} sec."
#    1011         " Please try increasing the timeout with the `init_timeout`"
#    1012         " setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`."
#    1013     )
#    1015 assert result.run_result
#    1017 if error := ProtobufErrorHandler.to_exception(result.run_result.error):
#
# CommError: Run initialization has timed out after 90.0 sec. Please try increasing the timeout with the `init_timeout` setting: `wandb.init(settings=wandb.Settings(init_timeout=120))`.

# %% [markdown]
# From here on, we have some standard CIFAR training definitions.

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
net = Net()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)

# %% [markdown]
# ### Training with wandb
#
# As you can see, similar to tensorboard, each gradient step we will want to log the accuracy and loss. See below for an example.

# %%
for epoch in range(epochs):  # loop over the dataset multiple times
    running_loss = 0.0
    running_acc = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        accuracy = torch.mean((torch.argmax(outputs, dim=1) == labels).float()).item() * 100

        # print statistics
        running_acc += accuracy
        running_loss += loss.item()
        if i % log_freq == log_freq - 1:
            wandb.log({'accuracy': accuracy, 'loss': loss.item()})
            
        if i % print_freq == print_freq - 1:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.5f} accuracy: {running_acc/print_freq:.5f}')
            running_loss = 0.0
            running_acc = 0.0
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x1407ce430>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1443, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/opt/anaconda3/envs/cs182hw1/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[20], line 22
#      20 running_loss += loss.item()
#      21 if i % log_freq == log_freq - 1:
# ---> 22     wandb.log({'accuracy': accuracy, 'loss': loss.item()})
#      24 if i % print_freq == print_freq - 1:    # print every 2000 mini-batches
#      25     print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.5f} accuracy: {running_acc/print_freq:.5f}')
#
# File /opt/anaconda3/envs/cs182hw1/lib/python3.8/site-packages/wandb/sdk/lib/preinit.py:36, in PreInitCallable.<locals>.preinit_wrapper(*args, **kwargs)
#      35 def preinit_wrapper(*args: Any, **kwargs: Any) -> Any:
# ---> 36     raise wandb.Error(f"You must call wandb.init() before {name}()")
#
# Error: You must call wandb.init() before wandb.log()

# %% [markdown]
# After we are done with this run, we will want to call
#  `wandb.finish()`

# %%
wandb.finish()

# %% [markdown]
# ## Your Task
# We will be once again building classifiers for the CIFAR-10. There are various architectures set up for you to use in the architectures.py file. Using wandb, please search through 10 different hyperparameter configurations. Examples of choices include: learning rate, batch size, architecture, optimization algorithm, etc. Please submit the hyperparameters that result in the highest accuracies for this classification task. Please then explore wandb for all the visualization that you may need. In addition, feel free to run as many epochs as you like.

# %%
def run(params):
    raise NotImplementedError

# %% [markdown]
# This software/tutorial is based on PyTorch, an open-source project available at https://github.com/pytorch/tutorials/
#
# There is a BSD 3-Clause License as seen here: https://github.com/pytorch/tutorials/blob/main/LICENSE
